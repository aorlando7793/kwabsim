# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from cavityclass import *

LAM = 1064*10**(-7)

# %%
ds28 = Cavity('datatest.dat', LAM)
# Out:
# Cavity is Unstable :(

# %%
ds28.waist(40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-906c0a8b8baf> in <module>()
# ----> 1 ds28.waist(40)
#
# ~\Python\kwabsim-master\cavityclass.py in waist(self, z)
#     196
#     197         def waist(self, z):
# --> 198                 z0 = self.q(z).real
#     199                 zR = self.q(z).imag
#     200                 waist = np.sqrt((4*self.lam/math.pi)*(zR + ((z0)**2)/zR))
#
# ~\Python\kwabsim-master\cavityclass.py in q(self, z)
#     182         def q(self, z):
#     183                 #free_space = [optic for optic in self.cavity if optic[0] == 'D']
# --> 184                 q = self.q0
#     185                 d = 0 #running cumulative distance of free space elements
#     186                 for optic in self.cavity:
#
# AttributeError: 'Cavity' object has no attribute 'q0'

# %%
ds28.plot_waist(1000)
plt.show()

# %%
ds28.remove_optic(9)

# %%
print(ds28.cavity)
# Out:
# [['M', 200.0], ['D', 24.0], ['M', -70.0], ['D', 4.5], ['L', 16.7], ['D', 2.0], ['M', -100.0], ['D', 10.0], ['D', 23.0], ['M', -200.0]]

# %%
ds28.plot_waist(1000)
plt.show()

# %%
ds28.insert_optic('L', 100, 9)
print(ds28.cavity)
# Out:
# [['M', 200.0], ['D', 24.0], ['M', -70.0], ['D', 4.5], ['L', 16.7], ['D', 2.0], ['M', -100.0], ['D', 10.0], ['L', 100], ['D', 23.0], ['M', -200.0]]

# %%
ds28.remove_optic(10)
ds28.insert_optic('D', 1, 10)
ds28.insert_optic('L', 30, 11)
ds28.insert_optic('D', 22, 12)

# %%
print(ds28.cavity)
# Out:
# [['M', 200.0], ['D', 24.0], ['M', -70.0], ['D', 4.5], ['L', 16.7], ['D', 2.0], ['M', -100.0], ['D', 10.0], ['L', 100], ['D', 1], ['L', 30], ['D', 22], ['M', -200.0]]

# %%
ds28.plot_waist(1000)
plt.show()

# %%
ds28.waist(40)
# Out:
# 0.083984193340630731
